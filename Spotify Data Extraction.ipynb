# %%
# !pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_credentials_manager=SpotifyClientCredentials(client_id='b0c923046050492aac1313d041504609',client_secret='d8f6ea62f30c4916bcb389515746ae49')

# %%
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
play_list_link= "https://open.spotify.com/playlist/37i9dQZEVXbMDoHDwVN2tF"

# %%
playlist_id=play_list_link.split("/")[-1]

# %%
data_extraction = sp.playlist_tracks(playlist_id)

# %%
data_extraction['items'][0].keys()
# Out:
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])

# %%
for albums in data_extraction['items']:
    for
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#   'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#   'id': '66CXWjxzNUsdJxJ2JdwvnR',
#   'name': 'Ariana Grande',
#   'type': 'artist',
#   'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'}]

# %%
albums=[]
for album in data_extraction['items']:
     albums.append({"album_id": album['track']['album']['id'],
                    "album_name": album['track']['album']['name'],
                    "release_date": album['track']['album']['release_date'],
                    "album_href":album['track']['album']['href'],
                    "external_urls":album['track']['album']['external_urls']['spotify']})

# %%
albums
# Out:
# [{'album_id': '5EYKrEDnKhhcNxGedaRQeK',
#   'album_name': 'eternal sunshine',
#   'release_date': '2024-03-08',
#   'album_href': 'https://api.spotify.com/v1/albums/5EYKrEDnKhhcNxGedaRQeK',
#   'external_urls': 'https://open.spotify.com/album/5EYKrEDnKhhcNxGedaRQeK'},
#  {'album_id': '29aSKB1qPEbN0Qf9OPSQpw',
#   'album_name': 'Beautiful Things',
#   'release_date': '2024-01-18',
#   'album_href': 'https://api.spotify.com/v1/albums/29aSKB1qPEbN0Qf9OPSQpw',
#   'external_urls': 'https://open.spotify.com/album/29aSKB1qPEbN0Qf9OPSQpw'},
#  {'album_id': '4JDXBZdRPId4devseaAOKH',
#   'album_name': 'DECIDE',
#   'release_date': '2022-09-16',
#   'album_href': 'https://api.spotify.com/v1/albums/4JDXBZdRPId4devseaAOKH',
#   'external_urls': 'https://open.spotify.com/album/4JDXBZdRPId4devseaAOKH'},
#  {'album_id': '30zwjSQEodaUXCn11nmiVF',
#   'album_name': 'VULTURES 1',
#   'release_date': '2024-02-09',
#   'album_href': 'https://api.spotify.com/v1/albums/30zwjSQEodaUXCn11nmiVF',
# ...

# %%
data_extraction['items'][2]['added_by']
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#  'href': 'https://api.spotify.com/v1/users/',
#  'id': '',
#  'type': 'user',
#  'uri': 'spotify:user:'}

# %%
Date = data_extraction['items'][2]['added_at']
Title=data_extraction['items'][2]['track']['name']

# %%
Title
# Out:
# 'End of Beginning'

# %%
data_extraction['items'][2]['track'].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'episode', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track', 'track_number', 'type', 'uri'])

# %%
popularity = data_extraction['items'][2]['track']['popularity']

# %%
album_name=data_extraction['items'][2]['track']['album']['name']
release_date=data_extraction['items'][2]['track']['album']['release_date']

# %%
release_date
# Out:
# '2024-02-10'

# %%
data_extraction['items'][2]['track']
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#     'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#     'id': '6vWDO969PvNqNYHIOW5v0m',
#     'name': 'Beyoncé',
#     'type': 'artist',
#     'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
# ...

# %%
data_extraction['items'][2]['track']['album']['name']
# Out:
# "TEXAS HOLD 'EM"

# %%
data_extraction['items'][2]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#   'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#   'id': '6vWDO969PvNqNYHIOW5v0m',
#   'name': 'Beyoncé',
#   'type': 'artist',
#   'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}]

# %%
data_extraction.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
data_extraction['items'][1]['track']['available_markets']
# Out:
# ['AR',
#  'AU',
#  'AT',
#  'BE',
#  'BO',
#  'BR',
#  'BG',
#  'CA',
#  'CL',
#  'CO',
#  'CR',
#  'CY',
#  'CZ',
#  'DK',
#  'DO',
#  'DE',
#  'EC',
#  'EE',
#  'SV',
#  'FI',
#  'FR',
#  'GR',
#  'GT',
#  'HN',
#  'HK',
#  'HU',
#  'IS',
#  'IE',
#  'IT',
#  'LV',
#  'LT',
#  'LU',
#  'MY',
#  'MT',
#  'MX',
#  'NL',
#  'NZ',
#  'NI',
#  'NO',
#  'PA',
#  'PY',
#  'PE',
#  'PH',
#  'PL',
#  'PT',
#  'SG',
#  'SK',
#  'ES',
#  'SE',
#  'CH',
#  'TW',
#  'TR',
#  'UY',
#  'US',
#  'GB',
#  'AD',
#  'LI',
#  'MC',
#  'ID',
#  'JP',
#  'TH',
#  'VN',
#  'RO',
#  'IL',
#  'ZA',
#  'SA',
#  'AE',
#  'BH',
#  'QA',
#  'OM',
#  'KW',
#  'EG',
#  'MA',
#  'DZ',
#  'TN',
#  'LB',
#  'JO',
#  'PS',
#  'IN',
#  'BY',
#  'KZ',
#  'MD',
#  'UA',
#  'AL',
#  'BA',
#  'HR',
#  'ME',
#  'MK',
#  'RS',
#  'SI',
#  'KR',
#  'BD',
#  'PK',
#  'LK',
#  'GH',
#  'KE',
#  'NG',
#  'TZ',
#  'UG',
#  'AG',
#  'AM',
#  'BS',
#  'BB',
#  'BZ',
#  'BT',
#  'BW',
#  'BF',
#  'CV',
#  'CW',
#  'DM',
#  'FJ',
# ...

# %%
data_extraction['items'][1]['track']['album']['name']
# Out:
# 'VULTURES 1'

# %%
data_extraction['items'][1]['track']
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4xPQFgDA5M2xa0ZGo5iIsv'},
#     'href': 'https://api.spotify.com/v1/artists/4xPQFgDA5M2xa0ZGo5iIsv',
#     'id': '4xPQFgDA5M2xa0ZGo5iIsv',
#     'name': '¥$',
#     'type': 'artist',
#     'uri': 'spotify:artist:4xPQFgDA5M2xa0ZGo5iIsv'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#     'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#     'id': '5K4W6rqBFWDnAN6FQUkS6x',
#     'name': 'Kanye West',
#     'type': 'artist',
#     'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7c0XG5cIJTrrAgEC3ULPiq'},
#     'href': 'https://api.spotify.com/v1/artists/7c0XG5cIJTrrAgEC3ULPiq',
#     'id': '7c0XG5cIJTrrAgEC3ULPiq',
#     'name': 'Ty Dolla $ign',
#     'type': 'artist',
#     'uri': 'spotify:artist:7c0XG5cIJTrrAgEC3ULPiq'}],
# ...
